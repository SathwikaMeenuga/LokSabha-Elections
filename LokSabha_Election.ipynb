# %% [markdown]
# # Libraries

# %%
pip install pandas

# %%
# !pip install gdown

# %%
import pandas as pd
import numpy as np
import gdown
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('fivethirtyeight') #predefined style

# %% [markdown]
# # Loading the Data

# %%
candidate_2004 = pd.read_csv('/LokSabha2004.csv')
candidate_2004.head()
# Out:
#            Candidate Party  Criminal Cases      Education  Age  Total Assets  \
# 0  Manoranjan Bhakta   INC               0  Post Graduate   65     5926740.0
# 1         A K Biswas   BSP               0       Graduate   61     7876500.0
# 2   Asit Baran Dutta   IND               0       Graduate   50     3070000.0
# 3    Bishnu Pada Ray   BJP               0       Graduate   54     1250619.0
# 4      Deepak Biswas   IND               0      Not Given   28        3000.0
#
#                 Constituency  Liabilities  Winner Gender
# 0  Andaman & Nicobar Islands       272061       1      M
# 1  Andaman & Nicobar Islands        65000       0      M
# 2  Andaman & Nicobar Islands            0       0      M
# 3  Andaman & Nicobar Islands       128710       0      M
# 4  Andaman & Nicobar Islands            0       0      M

# %%
candidate_2009 = pd.read_csv('/LokSabha2009.csv')
candidate_2009.head()
# Out:
#                  Candidate Party  Criminal Cases      Education  Age  \
# 0     Shri Bishnu Pada Ray   BJP               1       Graduate   59
# 1      Shri P. R. Ganeshan   RJD               0      Not Given   71
# 2  Shri Pradeep Kumar Ekka   JDP               0         Others   37
# 3              Shri T. Ali   IND               0      12th Pass   37
# 4  Shri Tapan Kumar Bepari   CPM               0  Post Graduate   52
#
#    Total Assets               Constituency  Liabilities  Winner Gender
# 0     1241034.0  Andaman & Nicobar Islands            0       0      M
# 1      329563.0  Andaman & Nicobar Islands            0       0      M
# 2      410000.0  Andaman & Nicobar Islands            0       0      M
# 3      445957.0  Andaman & Nicobar Islands       296000       0      M
# 4     3986000.0  Andaman & Nicobar Islands            0       0      M

# %%
candidate_2014 = pd.read_csv('/LokSabha2014.csv')
candidate_2014.head()
# Out:
#                Candidate Party  Criminal Cases  Education  Age  Total Assets  \
# 0        Bishnu Pada Ray   BJP               1   Graduate   64     5658980.0
# 1              A Pandian  AIFB               0  12th Pass   41      859410.0
# 2           Anita Mondal  AITC               1   Graduate   48     5471073.0
# 3         C G Saji Kumar   IND               0  12th Pass   41       50000.0
# 4  Gaur Chandra Majumder   BSP               0   Graduate   47     3192819.0
#
#                   Constituency  Liabilities  Winner Gender
# 0  ANDAMAN AND NICOBAR ISLANDS       175115     0.0      M
# 1  ANDAMAN AND NICOBAR ISLANDS       350000     0.0      M
# 2  ANDAMAN AND NICOBAR ISLANDS         6000     0.0      M
# 3  ANDAMAN AND NICOBAR ISLANDS            0     0.0      M
# 4  ANDAMAN AND NICOBAR ISLANDS       688689     0.0      M

# %%
candidate_2019 = pd.read_csv('/LokSabha2019.csv')
candidate_2019.head()
# Out:
#                Candidate                               Party  Criminal Cases  \
# 0     Kuldeep Rai Sharma                                 INC               0
# 1            Ayan Mandal                                AITC               0
# 2         C G Saji Kumar  All India Hindustan Congress Party               0
# 3            C U Rasheed                                 IND               0
# 4  Gour Chandra Majumder                                 IND               0
#
#                Education  Age  Total Assets                 Constituency  \
# 0  Graduate Professional   52   132233012.0  Andaman And Nicobar Islands
# 1               Graduate   30     7270440.0  Andaman And Nicobar Islands
# 2              12th Pass   48      120000.0  Andaman And Nicobar Islands
# 3              12th Pass   34      202808.0  Andaman And Nicobar Islands
# 4               Graduate   52     6062000.0  Andaman And Nicobar Islands
#
#    Liabilities  Winner Gender
# 0     80450870     1.0      M
# ...

# %%
candidate_2004['year']=2004
candidate_2009['year']=2009
candidate_2014['year']=2014
candidate_2019['year']=2019

# %%
candidate_2004
# Out:
#               Candidate Party  Criminal Cases              Education  Age  \
# 0     Manoranjan Bhakta   INC               0          Post Graduate   65
# 1            A K Biswas   BSP               0               Graduate   61
# 2      Asit Baran Dutta   IND               0               Graduate   50
# 3       Bishnu Pada Ray   BJP               0               Graduate   54
# 4         Deepak Biswas   IND               0              Not Given   28
# ...                 ...   ...             ...                    ...  ...
# 3637      Susmita Bauri   CPM               0  Graduate Professional   29
# 3638     Achintya Majhi   INC               0               Graduate   38
# 3639         Ajoy Bauri   BSP               0              Not Given   40
# 3640      Janardan Saha  AITC               0          Post Graduate   37
# 3641      Sraban Mondal   IND               0               Graduate   40
#
#       Total Assets               Constituency  Liabilities  Winner Gender  \
# ...

# %%
candidate_2019
# Out:
#                   Candidate                               Party  \
# 0        Kuldeep Rai Sharma                                 INC
# 1               Ayan Mandal                                AITC
# 2            C G Saji Kumar  All India Hindustan Congress Party
# 3               C U Rasheed                                 IND
# 4     Gour Chandra Majumder                                 IND
# ...                     ...                                 ...
# 7963         Maksuda Khatun                              CPI(M)
# 7964          Minati Sarkar                             SUCI(C)
# 7965   Shoma Ranisree Roy\t                                 INC
# 7966            Simal Saren                 Indian Unity Centre
# 7967    Susanta Kumar Dalui                                 IND
#
#       Criminal Cases              Education  Age  Total Assets  \
# 0                  0  Graduate Professional   52   132233012.0
# 1                  0               Graduate   30     7270440.0
# ...

# %%
candidates = pd.concat([candidate_2004,candidate_2009,candidate_2014,candidate_2019])

# %%
candidates.head()
# Out:
#            Candidate Party  Criminal Cases      Education  Age  Total Assets  \
# 0  Manoranjan Bhakta   INC               0  Post Graduate   65     5926740.0
# 1         A K Biswas   BSP               0       Graduate   61     7876500.0
# 2   Asit Baran Dutta   IND               0       Graduate   50     3070000.0
# 3    Bishnu Pada Ray   BJP               0       Graduate   54     1250619.0
# 4      Deepak Biswas   IND               0      Not Given   28        3000.0
#
#                 Constituency  Liabilities  Winner Gender  year
# 0  Andaman & Nicobar Islands       272061     1.0      M  2004
# 1  Andaman & Nicobar Islands        65000     0.0      M  2004
# 2  Andaman & Nicobar Islands            0     0.0      M  2004
# 3  Andaman & Nicobar Islands       128710     0.0      M  2004
# 4  Andaman & Nicobar Islands            0     0.0      M  2004

# %% [markdown]
# # Statistics

# %%
candidates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28014 entries, 0 to 7967
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Candidate       28014 non-null  object
#  1   Party           28014 non-null  object
#  2   Criminal Cases  28014 non-null  int64
#  3   Education       28014 non-null  object
#  4   Age             28014 non-null  int64
#  5   Total Assets    27199 non-null  float64
#  6   Constituency    28014 non-null  object
#  7   Liabilities     28014 non-null  int64
#  8   Winner          28014 non-null  float64
#  9   Gender          28014 non-null  object
#  10  year            28014 non-null  int64
# dtypes: float64(2), int64(4), object(5)
# memory usage: 2.6+ MB

# %%
candidates.describe()
# Out:
#        Criminal Cases           Age  Total Assets   Liabilities        Winner  \
# count    28014.000000  28014.000000  2.719900e+04  2.801400e+04  28014.000000
# mean         0.483901     46.487078  3.433395e+07  3.086273e+06      0.037660
# std          4.164205     12.546241  5.572976e+08  3.400576e+07      0.190375
# min          0.000000      0.000000  2.000000e+00  0.000000e+00      0.000000
# 25%          0.000000     37.000000  3.302960e+05  0.000000e+00      0.000000
# 50%          0.000000     46.000000  1.851000e+06  0.000000e+00      0.000000
# 75%          0.000000     55.000000  8.663450e+06  2.700000e+05      0.000000
# max        382.000000     94.000000  7.710296e+10  2.218003e+09      1.000000
#
#                year
# count  28014.000000
# mean    2012.708503
# std        5.050962
# min     2004.000000
# 25%     2009.000000
# 50%     2014.000000
# 75%     2019.000000
# max     2019.000000

# %%
candidates.shape
# Out:
# (28014, 11)

# %% [markdown]
# # YearWise Analysis

# %% [markdown]
# ## 1) Youngest Candidate

# %% [markdown]
# IN 2004

# %%
candidate_age_2004 = candidate_2004[candidate_2004['Age']>18]
candidate_age_2009 = candidate_2009[candidate_2009['Age']>18]
candidate_age_2014 = candidate_2014[candidate_2014['Age']>18]
candidate_age_2019 = candidate_2019[candidate_2019['Age']>18]

# %%
candidate_age_2004['Age'].min()
# Out:
# 25

# %%
candidate_age_2004[candidate_age_2004['Age'] == candidate_age_2004['Age'].min()].head()
# Out:
#                  Candidate  Party  Criminal Cases      Education  Age  \
# 393      Om Prakash Paswan     AD               0      Not Given   25
# 420         Sarjoon Paswan    IND               0      Not Given   25
# 550             Shakti Raj    BSP               0       Graduate   25
# 556          Monika Tiwari    BED               0  Post Graduate   25
# 569  Uttam Choudhary Unnat  JD(S)               0  Post Graduate   25
#
#      Total Assets Constituency  Liabilities  Winner Gender  year
# 393       15000.0       Araria         9000       0      M  2004
# 420      185000.0   Aurangabad            0       0      M  2004
# 550       94500.0         Gaya            0       0      M  2004
# 556       41000.0    Gopalganj            0       0      F  2004
# 569       20000.0      Hajipur            0       0      M  2004

# %% [markdown]
# IN 2009

# %%
candidate_age_2009['Age'].min()
# Out:
# 25

# %%
candidate_age_2009[candidate_age_2009['Age'] == candidate_age_2009['Age'].min()].head()
# Out:
#                  Candidate Party  Criminal Cases              Education  Age  \
# 570              Taba Taku    LB               0               Graduate   25
# 887          Binita Baitha   IND               0               Graduate   25
# 1017  Mohammad Nissar Alam   JMM               0               8th Pass   25
# 1128          Kumar Rajesh   IND               0               Graduate   25
# 1174  Durgesh Nandan Singh   IND               0  Graduate Professional   25
#
#       Total Assets    Constituency  Liabilities  Winner Gender  year
# 570        10000.0  Arunachal West            0       0      M  2009
# 887        80000.0       Gopalganj            0       0      F  2009
# 1017      206500.0      Kishanganj        45000       0      M  2009
# 1128           2.0         Nalanda            0       0      M  2009
# 1174       23000.0     Pataliputra            0       0      M  2009

# %% [markdown]
# IN 2014

# %%
candidate_age_2014['Age'].min()
# Out:
# 21

# %%
candidate_age_2014[candidate_age_2014['Age'] == candidate_age_2014['Age'].min()].head()
# Out:
#            Candidate Party  Criminal Cases Education  Age  Total Assets  \
# 7242  Ravikant Yadav   IND               0  Graduate   21     1100000.0
#
#      Constituency  Liabilities  Winner Gender  year
# 7242      JAUNPUR            0     0.0      M  2014

# %% [markdown]
# In 2019

# %%
candidate_age_2019['Age'].min()
# Out:
# 24

# %%
candidate_age_2019[candidate_age_2019['Age'] == candidate_age_2019['Age'].min()].head()
# Out:
#         Candidate Party  Criminal Cases  Education  Age  Total Assets  \
# 5774  Ponnuthai G   IND               0  12th Pass   24      118000.0
#
#      Constituency  Liabilities  Winner Gender  year
# 5774      Tenkasi            0     0.0      F  2019

# %% [markdown]
# Ravikant Yadav is the youngest candidate who participated in 2014 Loksabha Elections.

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=candidate_age_2004['Age'].sort_values(),palette="Dark2")
plt.xlabel('Age')
plt.ylabel('Count')
plt.title("Cadidate Age Count - 2004",fontsize=12)
plt.xticks(fontsize=12,rotation=90)
plt.show()
# Out:
# <ipython-input-112-4a5d9d739d77>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=candidate_age_2004['Age'].sort_values(),palette="Dark2")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=candidate_age_2009['Age'].sort_values(),palette="Dark2")
plt.title("Candidate Age Count - 2009")
plt.xlabel('Age')
plt.ylabel('Count')
plt.xticks (fontsize=12,rotation=90)
plt.show()
# Out:
# <ipython-input-114-3a19293bee35>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=candidate_age_2009['Age'].sort_values(),palette="Dark2")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=candidate_age_2014['Age'].sort_values(),palette="Dark2")
plt.xlabel('Age')
plt.ylabel('Count')
plt.title("Candidate Age Count - 2014",fontsize=12)
plt.xticks(fontsize=12,rotation=90)
plt.show()
# Out:
# <ipython-input-117-bba67c1342cc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=candidate_age_2014['Age'].sort_values(),palette="Dark2")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=candidate_age_2019['Age'].sort_values(),palette="Dark2")
plt.xlabel('Age')
plt.ylabel('Count')
plt.title("Candidate Age Counr - 2019",fontsize=12)
plt.xticks(fontsize=12,rotation=90)
plt.show()
# Out:
# <ipython-input-119-0f64d3d49750>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=candidate_age_2019['Age'].sort_values(),palette="Dark2")

# %%
candidates['Age'].value_counts()
# Out:
# Age
# 38    904
# 43    898
# 42    875
# 39    869
# 40    859
#      ...
# 85      1
# 4       1
# 87      1
# 90      1
# 24      1
# Name: count, Length: 71, dtype: int64

# %% [markdown]
# There are 904 candidates who are 38 years old.

# %% [markdown]
# ## 2)Candidates with Highest Criminal Cases

# %%
candidate_2004['Criminal Cases'].max()
# Out:
# 36

# %%
candidate_2004[candidate_2004['Criminal Cases'] == candidate_2004['Criminal Cases'].max()]
# Out:
#           Candidate Party  Criminal Cases Education  Age  Total Assets  \
# 3144  Atique Ahamad    SP              36  8th Pass   41    33704071.0
#
#      Constituency  Liabilities  Winner Gender  year
# 3144      Phulpur            0       0      M  2004

# %%
candidate_2009['Criminal Cases'].max()
# Out:
# 46

# %%
candidate_2009[candidate_2009['Criminal Cases'] == candidate_2009['Criminal Cases'].max()]
# Out:
#              Candidate Party  Criminal Cases  Education  Age  Total Assets  \
# 2427  Kameshwar Baitha   JMM              46  10th Pass   56      570000.0
#
#      Constituency  Liabilities  Winner Gender  year
# 2427      Palamau            0       0      M  2009

# %%
candidate_2014['Criminal Cases'].max()
# Out:
# 382

# %%
candidate_2014[candidate_2014['Criminal Cases'] == candidate_2014['Criminal Cases'].max()]
# Out:
#             Candidate Party  Criminal Cases  Education  Age  Total Assets  \
# 5714  Udayakumar S.P.   AAP             382  Doctorate   54    52080000.0
#
#        Constituency  Liabilities  Winner Gender  year
# 5714  KANNIYAKUMARI       297000     0.0      M  2014

# %%
candidate_2019['Criminal Cases'].max()
# Out:
# 240

# %%
candidate_2019[candidate_2019['Criminal Cases'] == candidate_2019['Criminal Cases'].max()]
# Out:
#         Candidate Party  Criminal Cases Education  Age  Total Assets  \
# 2908  K Surendran   BJP             240  Graduate   49     4044300.0
#
#         Constituency  Liabilities  Winner Gender  year
# 2908  Pathanamthitta      1308799     0.0      M  2019

# %%
candidates.sort_values(['Criminal Cases'],ascending=False).head().style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_71354_row0_col2, #T_71354_row0_col4, #T_71354_row2_col10, #T_71354_row3_col7, #T_71354_row3_col10, #T_71354_row4_col4, #T_71354_row4_col5, #T_71354_row4_col10 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_71354_row0_col5 {
#   background-color: #fdcdb9;
#   color: #000000;
# }
# #T_71354_row0_col7 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_71354_row0_col8, #T_71354_row0_col10, #T_71354_row1_col7, #T_71354_row1_col8, #T_71354_row1_col10, #T_71354_row2_col5, #T_71354_row2_col8, #T_71354_row3_col4, #T_71354_row3_col8, #T_71354_row4_col2, #T_71354_row4_col7, #T_71354_row4_col8 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_71354_row1_col2 {
#   background-color: #69000d;
#   color: #f1f1f1;
# }
# #T_71354_row1_col4 {
#   background-color: #f85f43;
#   color: #f1f1f1;
# }
# #T_71354_row1_col5 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_71354_row2_col2 {
#   background-color: #f5533b;
# ...

# %% [markdown]
# Candidate Udayakumar S.P. has 382 criminal cases

# %% [markdown]
# ## 3) Candidates participating from 2004

# %%
candidates['Party'].value_counts()
# Out:
# Party
# IND                       11725
# BSP                        1724
# INC                        1715
# BJP                        1643
# SP                          617
#                           ...
# Nehru Janhit Congress         1
# MMM                           1
# Shoshit Sandesh Party         1
# Parcham Party of India        1
# Jan Sangh Party               1
# Name: count, Length: 1332, dtype: int64

# %%
loc = candidates['Party'].value_counts()
sns.set(style="darkgrid")
sns.barplot(
    x=loc[:10],
    y=loc[:10].index,
    palette = "rainbow"
)
plt.xlabel('party')
plt.ylabel('count')
plt.title("Candidates in each party")
plt.show()
# Out:
# <ipython-input-144-76878ed65b7f>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## 4) Candidate Education Levels

# %%
candidates['Education'].value_counts()
# Out:
# Education
# Graduate                 5305
# Post Graduate            4606
# 10th Pass                4082
# 12th Pass                3773
# Graduate Professional    2715
# 8th Pass                 2150
# Not Given                1276
# Literate                 1181
# 5th Pass                 1167
# Others                    709
# Doctorate                 672
# Illiterate                378
# Name: count, dtype: int64

# %%
candidates['Education'].value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='Education'>

# %%
candidates['Education'].value_counts().plot.pie(autopct='%1.1f%%', figsize=(8, 8))
plt.xlabel('Education')
plt.ylabel('Count')
plt.show()
